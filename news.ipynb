# %%
import requests
import pandas as pd

url = "https://newsapi.org/v2/everything?q=stock market&language=en&sortBy=publishedAt&apiKey=d406db3b904248e1af2c59cdf1327a80&from=2025-04-27&to=2025-04-27"

response = requests.get(url)
data = response.json()

# Controlla che la richiesta sia andata a buon fine
if data["status"] == "ok":
    articles = data["articles"]
    df = pd.DataFrame([{
        "publishedAt": article["publishedAt"],
        "source": article["source"]["name"],
        "author": article.get("author"),
        "title": article["title"],
        "description": article.get("description"),
        "url": article["url"],
        "content": article.get("content")
    } for article in articles])

    print(f"Notizie trovate: {df.shape[0]}")
else:
    print("Errore nella richiesta:", data)
# Out:
# Notizie trovate: 0

# %%
df
# Out:
#              publishedAt               source            author  \
# 0   2025-04-24T23:55:54Z           Biztoc.com     bloomberg.com
# 1   2025-04-24T23:55:49Z           Biztoc.com      benzinga.com
# 2   2025-04-24T23:54:12Z       The New Yorker  Susan B. Glasser
# 3   2025-04-24T23:52:16Z         Slashdot.org        feedfeeder
# 4   2025-04-24T23:45:00Z  Yahoo Entertainment  Amalya Dubrovsky
# ..                   ...                  ...               ...
# 93  2025-04-24T20:25:02Z             Wccftech     Rohail Saleem
# 94  2025-04-24T20:20:21Z         Wonkette.com      Marcie Jones
# 95  2025-04-24T20:16:31Z       Financial Post     GlobeNewswire
# 96  2025-04-24T20:15:06Z                 CNBC              None
# 97  2025-04-24T20:15:02Z     Macdailynews.com      MacDailyNews
#
#                                                 title  \
# 0   Oil Set for Weekly Loss With Focus on US-China...
# 1   Here's How Much You Would Have Made Owning Ext...
# 2             Where Are Trump’s Big, Beautiful Deals?
# 3   Dow Jones Today: Stocks Surge for 3rd Straight...
# 4   Stock market today: Dow, S&P 500, Nasdaq futur...
# ..                                                ...
# 93  Intel Q1 2025 Earnings: Lip Bu-Tan Eschews Lay...
# 94  Trump Hardball With China Just Trump Getting K...
# 95  NCS Multistage Holdings, Inc. Schedules First ...
# 96  Intel issues weak guidance, says it will slash...
# 97  Apple primed to report strong Q225 earnings on...
#
#                                           description  \
# 0
# 1   Extra Space Storage (NYSE:EXR) has outperforme...
# 2   The President promised a slew of deals—peace i...
# 3   Dow Jones Today: Stocks Surge for 3rd Straight...
# 4   US stock futures held steady after Google pare...
# ..                                                ...
# 93  Intel likely benefited from the pull-forward o...
# 94               Dude, they're not going to call you.
# 95  HOUSTON, April 24, 2025 (GLOBE NEWSWIRE) — NCS...
# 96  In its first earnings report under the leaders...
# 97  Apple could report strong growth in quarterly ...
#
#                                                   url  \
# 0               https://biztoc.com/x/da096b8cc4dc6de6
# 1               https://biztoc.com/x/3dab3be0ead5cf9c
# 2   https://www.newyorker.com/news/letter-from-tru...
# 3   https://slashdot.org/firehose.pl?op=view&amp;i...
# 4   https://finance.yahoo.com/news/live/stock-mark...
# ..                                                ...
# 93  https://wccftech.com/intel-q1-2025-earnings-li...
# 94  https://www.wonkette.com/p/trump-hardball-with...
# 95  https://financialpost.com/globe-newswire/ncs-m...
# 96  https://www.cnbc.com/2025/04/24/intel-intc-q1-...
# 97  https://macdailynews.com/2025/04/24/apple-prim...
#
#                                               content
# 0   { window.open(this.href, '_blank'); }, 200); r...
# 1   Extra Space Storage (NYSE:EXR) has outperforme...
# 2   This week in Washington, the rare convergence ...
# 3   The Fine Print: The following comments are own...
# 4   US stock futures held steady after Google pare...
# ..                                                ...
# 93  This is not investment advice. The author has ...
# 94  The stock market paused its freefall on Tuesda...
# 95  HOUSTON, April 24, 2025 (GLOBE NEWSWIRE) NCS M...
# 96  Intel reported first-quarter results on Thursd...
# 97  Apple could report strong growth in quarterly ...
#
# [98 rows x 7 columns]

# %% [markdown]
# Facciamo sentiment analysis su titolo + descrizione, non su contenuto

# %%
import time
from datetime import datetime, timedelta
import requests
import pandas as pd

FROM_DATE = (datetime.now() - timedelta(hours=1)).strftime("%Y-%m-%dT%H:%M:%S") #minutes #seconds
TO_DATE = datetime.now().strftime("%Y-%m-%dT%H:%M:%S")

url = f"https://newsapi.org/v2/everything?q=stock market&language=en&sortBy=publishedAt&apiKey=d406db3b904248e1af2c59cdf1327a80&from={FROM_DATE}&to={TO_DATE}"
response = requests.get(url)
data = response.json()

# Controlla che la richiesta sia andata a buon fine
if data["status"] == "ok":
    articles = data["articles"]
    df = pd.DataFrame([{
        "publishedAt": article["publishedAt"],
        "source": article["source"]["name"],
        "author": article.get("author"),
        "title": article["title"],
        "description": article.get("description"),
        "url": article["url"],
        "content": article.get("content")
    } for article in articles])

    print(f"News found: {df.shape[0]}")
else:
    print("Errore nella richiesta:", data)
# Out:
# 2025-04-27T17:05:04
# 2025-04-27T18:05:04
# News found: 98

# %% [markdown]
# Ora si può chiedere ogni ora invece che ogni giorno, da provare domani visto che oggi pare non ci siano news. Capire poi come fare a far si che ogni ora mandi l'imput.
