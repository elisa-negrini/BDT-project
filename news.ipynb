# %%
import requests
import pandas as pd

url = "https://newsapi.org/v2/everything?q=stock market&language=en&sortBy=publishedAt&apiKey=d406db3b904248e1af2c59cdf1327a80&from=2025-04-23&to=2025-04-23"

response = requests.get(url)
data = response.json()

# Controlla che la richiesta sia andata a buon fine
if data["status"] == "ok":
    articles = data["articles"]
    df_news_org = pd.DataFrame([{
        "publishedAt": article["publishedAt"],
        "source": article["source"]["name"],
        "author": article.get("author"),
        "title": article["title"],
        "description": article.get("description"),
        "url": article["url"],
        "content": article.get("content")
    } for article in articles])

    print(f"Notizie trovate: {df_news_org.shape[0]}")
else:
    print("Errore nella richiesta:", data)
# Out:
# Notizie trovate: 99

# %%
df_news_org
# Out:
#              publishedAt                 source  \
# 0   2025-04-23T23:56:05Z             Biztoc.com
# 1   2025-04-23T23:55:46Z             Biztoc.com
# 2   2025-04-23T23:55:36Z             Biztoc.com
# 3   2025-04-23T23:38:29Z  Motley Fool Australia
# 4   2025-04-23T23:33:26Z             Biztoc.com
# ..                   ...                    ...
# 94  2025-04-23T20:44:32Z    Yahoo Entertainment
# 95  2025-04-23T20:41:39Z         Financial Post
# 96  2025-04-23T20:38:09Z        Newsbusters.org
# 97  2025-04-23T20:35:54Z           7NEWS.com.au
# 98  2025-04-23T20:35:50Z          seattlepi.com
#
#                                           author  \
# 0                                    barrons.com
# 1                                  bloomberg.com
# 2                                  bloomberg.com
# 3                                  Laura Stewart
# 4                                   barchart.com
# ..                                           ...
# 94                            Alexandra Semenova
# 95                            The Canadian Press
# 96  Joseph Vazquez Mrc Business Associate Editor
# 97                                         7news
# 98                          The Associated Press
#
#                                                 title  \
# 0       Gold Is Having a Moment. How Long It Can Last
# 1   Oil Holds Biggest Loss in Two Weeks With Focus...
# 2   BOJ Watchers Expect Delay in Rate Hikes With L...
# 3   How to play the 'sell America' trade with ASX ...
# 4   Analysts Think You Should Buy and Hold This 1 ...
# ..                                                ...
# 94  Exhausted by Trump Reversals, Traders Get No R...
# 95  S&P/TSX composite rises Wednesday, U.S. market...
# 96  DOW DOOM: CNN Cries Potential ‘Great Depressio...
# 97  Elon Musk makes big Tesla call as profits dive...
# 98  How major US stock indexes fared Wednesday, 4/...
#
#                                           description  \
# 0
# 1
# 2
# 3   ASX ETF investors have several options to dive...
# 4
# ..                                                ...
# 94  (Bloomberg) -- Any other time, it would have b...
# 95  TORONTO — Canada’s main stock index and U.S. m...
# 96  President Donald Trump’s first 100 days haven’...
# 97  The move comes as the billionaire faces backla...
# 98  U.S. stocks rose as a worldwide rally came bac...
#
#                                                   url  \
# 0               https://biztoc.com/x/ed4d37f9222be765
# 1               https://biztoc.com/x/c4c79dd65cdd32a7
# 2               https://biztoc.com/x/00e45f4b2d054184
# 3   https://www.fool.com.au/2025/04/24/how-to-play...
# 4               https://biztoc.com/x/6ce99bed9e05b481
# ..                                                ...
# 94  https://finance.yahoo.com/news/exhausted-trump...
# 95  https://financialpost.com/pmn/sp-tsx-composite...
# 96  https://www.newsbusters.org/blogs/business/jos...
# 97  https://7news.com.au/news/musk-to-spend-more-t...
# 98  https://www.seattlepi.com/business/article/how...
#
#                                               content
# 0   { window.open(this.href, '_blank'); }, 200); r...
# 1   { window.open(this.href, '_blank'); }, 200); r...
# 2   { window.open(this.href, '_blank'); }, 200); r...
# 3   In recent weeks, the 'sell America' trade has ...
# 4   { window.open(this.href, '_blank'); }, 200); r...
# ..                                                ...
# 94  (Bloomberg) Any other time, it would have been...
# 95  TORONTO Canadas main stock index and U.S. mark...
# 96  President Donald Trumps first 100 days havent ...
# 97  Elon Musk says he will dedicate more time to T...
# 98  U.S. stocks rose as a worldwide rally came bac...
#
# [99 rows x 7 columns]

# %% [markdown]
# Facciamo sentiment analysis su titolo + descrizione, non su contenuto

# %%
import time
from datetime import datetime, timedelta
import requests
import pandas as pd

FROM_DATE = (datetime.now() - timedelta(hours=1)).strftime("%Y-%m-%dT%H:%M:%S") #minutes #seconds
TO_DATE = datetime.now().strftime("%Y-%m-%dT%H:%M:%S")

url = f"https://newsapi.org/v2/everything?q=stock market&language=en&sortBy=publishedAt&apiKey=d406db3b904248e1af2c59cdf1327a80&from={FROM_DATE}&to={TO_DATE}"
response = requests.get(url)
data = response.json()

# Controlla che la richiesta sia andata a buon fine
if data["status"] == "ok":
    articles = data["articles"]
    df_news_org = pd.DataFrame([{
        "publishedAt": article["publishedAt"],
        "source": article["source"]["name"],
        "author": article.get("author"),
        "title": article["title"],
        "description": article.get("description"),
        "url": article["url"],
        "content": article.get("content")
    } for article in articles])

    print(f"News found: {df_news_org.shape[0]}")
else:
    print("Errore nella richiesta:", data)
# Out:
# News found: 0

# %% [markdown]
# Ora si può chiedere ogni ora invece che ogni giorno, da provare domani visto che oggi pare non ci siano news. Capire poi come fare a far si che ogni ora mandi l'imput.
