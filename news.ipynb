# %%
import requests
import pandas as pd

url = "https://newsapi.org/v2/everything?q=stock market&language=en&sortBy=publishedAt&apiKey=d406db3b904248e1af2c59cdf1327a80&from=2025-04-27&to=2025-04-27"

response = requests.get(url)
data = response.json()

# Controlla che la richiesta sia andata a buon fine
if data["status"] == "ok":
    articles = data["articles"]
    df = pd.DataFrame([{
        "publishedAt": article["publishedAt"],
        "source": article["source"]["name"],
        "author": article.get("author"),
        "title": article["title"],
        "description": article.get("description"),
        "url": article["url"],
        "content": article.get("content")
    } for article in articles])

    print(f"Notizie trovate: {df.shape[0]}")
else:
    print("Errore nella richiesta:", data)
# Out:
# Notizie trovate: 98

# %%
df
# Out:
#              publishedAt               source  \
# 0   2025-04-27T23:52:37Z           Biztoc.com
# 1   2025-04-27T23:52:31Z           Biztoc.com
# 2   2025-04-27T23:49:59Z  Yahoo Entertainment
# 3   2025-04-27T23:49:59Z  Yahoo Entertainment
# 4   2025-04-27T23:49:59Z  Yahoo Entertainment
# ..                   ...                  ...
# 93  2025-04-27T17:35:55Z             CBS News
# 94  2025-04-27T17:30:12Z               Forbes
# 95  2025-04-27T17:25:32Z        Cointelegraph
# 96  2025-04-27T17:17:02Z             HuffPost
# 97  2025-04-27T17:13:44Z           Biztoc.com
#
#                                                author  \
# 0                                         nytimes.com
# 1                                       bloomberg.com
# 2                                        Rian Howlett
# 3                                                None
# 4                                        Rian Howlett
# ..                                                ...
# 93                                               None
# 94  Francois Botha, Senior Contributor, \n Francoi...
# 95                       Cointelegraph by Vince Quill
# 96                                    Jazmin Tolliver
# 97                                      thestreet.com
#
#                                                 title  \
# 0   New Details Emerge on Trump Officials’ Sprint ...
# 1   BOJ to Hit Pause on Rate-Hike Path as Economic...
# 2   Stock market today: S&P 500, Dow, Nasdaq futur...
# 3   Stock market today: S&P 500, Dow, Nasdaq futur...
# 4   Stock market today: S&P 500, Dow, Nasdaq futur...
# ..                                                ...
# 93  Transcript: Gary Cohn on "Face the Nation with...
# 94  What Tech Workforce Changes Could Mean For Opp...
# 95  Federal taxes to be 'substantially reduced' on...
# 96  Trump Boldly Claims Steep Tariffs Could Lead T...
# 97  Analysts reset Palantir stock forecast amid rally
#
#                                           description  \
# 0
# 1
# 2   US futures slip slightly with investors focuse...
# 3                                                None
# 4   US futures were flat on Monday with investors ...
# ..                                                ...
# 93  The following is the transcript of an intervie...
# 94  Tech companies cutting workforce could have im...
# 95  United States President Donald Trump recently ...
# 96  “It will be a BONANZA FOR AMERICA!!!" the pres...
# 97  If one tech stock has done an excellent job th...
#
#                                                   url  \
# 0               https://biztoc.com/x/0ce02d66f922d83f
# 1               https://biztoc.com/x/0ca1273d00ecf619
# 2   https://finance.yahoo.com/news/live/stock-mark...
# 3   https://consent.yahoo.com/v2/collectConsent?se...
# 4   https://finance.yahoo.com/news/live/stock-mark...
# ..                                                ...
# 93  https://www.cbsnews.com/news/gary-cohn-ibm-fac...
# 94  https://www.forbes.com/sites/francoisbotha/202...
# 95  https://cointelegraph.com/news/federal-taxes-s...
# 96  https://www.huffpost.com/entry/trump-tariffs-t...
# 97              https://biztoc.com/x/5139cad9d42064a2
#
#                                               content
# 0   { window.open(this.href, '_blank'); }, 200); r...
# 1   { window.open(this.href, '_blank'); }, 200); r...
# 2   Stock futures edged lower ahead of a big week ...
# 3   If you click 'Accept all', we and our partners...
# 4   Stock futures were flat on Monday ahead of a b...
# ..                                                ...
# 93  The following is the transcript of an intervie...
# 94  The Intel headquarters in Santa Clara could en...
# 95  United States President Donald Trump recently ...
# 96  President Donald Trump has made a bold claim a...
# 97  If one tech stock has done an excellent job th...
#
# [98 rows x 7 columns]

# %% [markdown]
# Facciamo sentiment analysis su titolo + descrizione, non su contenuto

# %%
import time
from datetime import datetime, timedelta
import requests
import pandas as pd

FROM_DATE = (datetime.now() - timedelta(hours=1)).strftime("%Y-%m-%dT%H:%M:%S") #minutes #seconds
TO_DATE = datetime.now().strftime("%Y-%m-%dT%H:%M:%S")

url = f"https://newsapi.org/v2/everything?q=stock market&language=en&sortBy=publishedAt&apiKey=d406db3b904248e1af2c59cdf1327a80&from={FROM_DATE}&to={TO_DATE}"
response = requests.get(url)
data = response.json()

# Controlla che la richiesta sia andata a buon fine
if data["status"] == "ok":
    articles = data["articles"]
    df = pd.DataFrame([{
        "publishedAt": article["publishedAt"],
        "source": article["source"]["name"],
        "author": article.get("author"),
        "title": article["title"],
        "description": article.get("description"),
        "url": article["url"],
        "content": article.get("content")
    } for article in articles])

    print(f"News found: {df.shape[0]}")
else:
    print("Errore nella richiesta:", data)
# Out:
# News found: 0

# %% [markdown]
# Ora si può chiedere ogni ora invece che ogni giorno, da provare domani visto che oggi pare non ci siano news. Capire poi come fare a far si che ogni ora mandi l'imput.
